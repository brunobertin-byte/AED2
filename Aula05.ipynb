# %%
class Automovel:
     def __init__(self, placa):
        self.placa = placa
        
     def get_placa(self):
       return self.placa
       
meu_carro = Automovel(‘XZX1234’)
print(meu_carro.get_placa())
# Out:
#   File <string>:5
#     def get_placa(self):
#                         ^
# IndentationError: unindent does not match any outer indentation level

# %%
class Automovel:
   pass

# %%
meu_carro = Automovel()

# %%
print(meu_carro)
# Out:
# <__main__.Automovel object at 0x0000022D20F38C20>

# %%
class Automovel:
    def __init__(self, placa):
        self.placa = placa

# %%
meu_carro = Automovel ('EEQ-9C96')

# %%
print(meu_carro.placa)
# Out:
# EEQ-9C96

# %%
class Automovel:
    def __init__(self, placa):
        self.placa = placa

    def get_placa(self):
        return self.placa


# Criando o objeto
meu_carro = Automovel('EEQ-6C96')

# Exibindo a placa inicial
print(meu_carro.get_placa())

# Alterando a placa diretamente
meu_carro.placa = 'BRU-1012'

# Exibindo a nova placa
print(meu_carro.get_placa())
# Out:
# EEQ-6C96
# BRU-1012

# %%
class Automovel:
    def __init__(self, placa):
        self.placa = placa

    def get_placa(self):
        return self.placa

    def dirigir(self, velocidade):
        print(f"Estou dirigindo a {velocidade} km/h")


# Criando o objeto
meu_carro = Automovel('EEQ-6C96')

# Exibindo a placa
print(meu_carro.get_placa())

# Chamando o método corretamente
meu_carro.dirigir(100)
# Out:
# EEQ-6C96
# Estou dirigindo a 100 km/h

# %%
class Automovel:
    def __init__(self, placa, velocidade_max):
        self.placa = placa
        self.velocidade_max = velocidade_max

    def to_str(self):
        return f"{self.velocidade_max} Km/h"

    def get_placa(self):
        return self.placa

    def dirigir(self, velocidade):
        print(f"Estou dirigindo a {velocidade} km/h")


# Criando o objeto (faltava o segundo argumento)
meu_carro = Automovel('EEQ-6C96', 180)

# Exibindo a placa
print(meu_carro.get_placa())

# Chamando o método corretamente
meu_carro.dirigir(100)

# Exibindo a velocidade máxima
print(meu_carro.to_str())
# Out:
# EEQ-6C96
# Estou dirigindo a 100 km/h
# 180 Km/h

# %%
class Automovel:
    def __init__(self, placa, velocidade_max):
        self.placa = placa
        self.velocidade_max = velocidade_max
        self.velocidade_atual = 0

    def __str__(self):
        return f"{self.velocidade_atual} Km/h"

    def get_placa(self):
        return self.placa

    def acelerar(self, incremento):
        if self.velocidade_atual + incremento <= self.velocidade_max:
            self.velocidade_atual += incremento
        else:
            self.velocidade_atual = self.velocidade_max
        print(f"Velocidade atual: {self.velocidade_atual} km/h")

    def frear(self, decremento):
        if self.velocidade_atual - decremento >= 0:
            self.velocidade_atual -= decremento
        else:
            self.velocidade_atual = 0
        print(f"Velocidade atual: {self.velocidade_atual} km/h")


# Criando o objeto
meu_carro = Automovel('EEQ-6C96', 180)

# Testando os métodos
print(meu_carro.get_placa())
meu_carro.acelerar(50)
meu_carro.acelerar(200)  # testa limite máximo
meu_carro.frear(30)
print(meu_carro)
# Out:
# EEQ-6C96
# Velocidade atual: 50 km/h
# Velocidade atual: 180 km/h
# Velocidade atual: 150 km/h
# 150 Km/h

# %%
class Automovel:
    def __init__(self, placa, velocidade_max):
        self.placa = placa
        self.velocidade_max = velocidade_max
        self.velocidade_atual = 0

    def __str__(self):
        return f"{self.velocidade_atual} Km/h"

    def get_placa(self):
        return self.placa

    def acelerar(self):
        maxima = self.velocidade_max
        nova = self.velocidade_atual + 10
        self.velocidade_atual = nova if nova <= maxima else maxima

    def frear(self):
        nova = self.velocidade_atual - 10
        self.velocidade_atual = nova if nova >= 0 else 0


# Criando o objeto
meu_carro = Automovel('EEQ-6C96', 180)

# Testando
print(meu_carro.get_placa())
print(meu_carro)

meu_carro.acelerar()
meu_carro.acelerar()
print(meu_carro)

meu_carro.frear()
print(meu_carro)
# Out:
# EEQ-6C96
# 0 Km/h
# 20 Km/h
# 10 Km/h

# %%
class Automovel:
    def __init__(self, placa, velocidade_max):
        self.placa = placa
        self.velocidade_max = velocidade_max
        self.velocidade_atual = 0

    def __str__(self):
        return f"{self.velocidade_atual} Km/h"

    def get_placa(self):
        return self.placa

    def acelerar(self):
        maxima = self.velocidade_max
        nova = self.velocidade_atual + 10
        self.velocidade_atual = nova if nova <= maxima else maxima

    def frear(self):
        nova = self.velocidade_atual - 10
        self.velocidade_atual = nova if nova >= 0 else 0


# Exemplo de uso
meu_carro = Automovel('EEQ-6C96', 180)

print(meu_carro)  # 0 Km/h

meu_carro.acelerar()
meu_carro.acelerar()
print(meu_carro)  # 20 Km/h

meu_carro.frear()
print(meu_carro)  # 10 Km/h
# Out:
# 0 Km/h
# 20 Km/h
# 10 Km/h

# %%
class Automovel:
    def __init__(self, placa, velocidade_max):
        self.__placa = placa
        self.__velocidade_max = velocidade_max
        self.__velocidade_atual = 0

    def __str__(self):
        return f"{self.__velocidade_atual} Km/h"

    def get_placa(self):
        return self.__placa

    def acelerar(self):
        maxima = self.__velocidade_max
        nova = self.__velocidade_atual + 10
        self.__velocidade_atual = nova if nova <= maxima else maxima

    def frear(self):
        nova = self.__velocidade_atual - 10
        self.__velocidade_atual = nova if nova >= 0 else 0


# Exemplo de uso
meu_carro = Automovel('EEQ-6C96', 180)

print(meu_carro.get_placa())
print(meu_carro)

meu_carro.acelerar()
meu_carro.acelerar()
print(meu_carro)

meu_carro.frear()
print(meu_carro)
# Out:
# EEQ-6C96
# 0 Km/h
# 20 Km/h
# 10 Km/h

# %%
class Automovel:
    def __init__(self, placa, velocidade_max):
        self.__placa = placa
        self.__velocidade_max = velocidade_max
        self.__velocidade_atual = 0

    def __str__(self):
        return f"{self.__velocidade_atual} Km/h"

    def get_placa(self):
        return self.__placa

    def get_velocidade_max(self):
        return self.__velocidade_max

    def set_velocidade_max(self, nova):
        self.__velocidade_max = nova

    def acelerar(self):
        maxima = self.__velocidade_max
        nova = self.__velocidade_atual + 10
        self.__velocidade_atual = nova if nova <= maxima else maxima

    def frear(self):
        nova = self.__velocidade_atual - 10
        self.__velocidade_atual = nova if nova >= 0 else 0


# Teste
meu_carro = Automovel('XZX1234', 180)

print(meu_carro)
meu_carro.acelerar()
meu_carro.acelerar()
print(meu_carro)

meu_carro.frear()
print(meu_carro)

print("Velocidade máxima:", meu_carro.get_velocidade_max())
meu_carro.set_velocidade_max(200)
print("Nova velocidade máxima:", meu_carro.get_velocidade_max())
# Out:
# 0 Km/h
# 20 Km/h
# 10 Km/h
# Velocidade máxima: 180
# Nova velocidade máxima: 200

# %%
class Automovel:
    contador = 0
    precisao = 0.95  # 5%

    def __init__(self, placa, velocidade_max):
        self.__id = Automovel.contador + 1
        self.__placa = placa
        self.__velocidade_max = velocidade_max * Automovel.precisao
        self.__velocidade_atual = 0
        Automovel.contador = self.__id

    def __str__(self):
        return f"{self.__id} - {self.__velocidade_atual} Km/h"

    def get_placa(self):
        return self.__placa

    def get_velocidade_max(self):
        return self.__velocidade_max

    def set_velocidade_max(self, nova):
        self.__velocidade_max = nova

    def acelerar(self):
        maxima = self.__velocidade_max
        nova = self.__velocidade_atual + 10
        self.__velocidade_atual = nova if nova <= maxima else maxima

    def frear(self):
        nova = self.__velocidade_atual - 10
        self.__velocidade_atual = nova if nova >= 0 else 0


# Testando
carro1 = Automovel('ABC1234', 180)
carro2 = Automovel('XYZ9999', 200)

print(carro1)
print(carro2)

carro1.acelerar()
carro1.acelerar()
print(carro1)

carro1.frear()
print(carro1)

print("Velocidade máxima:", carro1.get_velocidade_max())
# Out:
# 1 - 0 Km/h
# 2 - 0 Km/h
# 1 - 20 Km/h
# 1 - 10 Km/h
# Velocidade máxima: 171.0

# %%
# !pip install passlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: passlib in c:\users\alunos\appdata\roaming\python\python313\site-packages (1.7.4)

# %%
from passlib.hash import pbkdf2_sha256 as crip

class Usuario:
    def __init__(self, nome, sobrenome, email, senha):
        self.__nome = nome
        self.__sobrenome = sobrenome
        self.__email = email
        # Gerando hash da senha com parâmetros rounds=1000 e salt_size=10
        self.__senha = crip.encrypt(senha, rounds=1000, salt_size=10)

    def nome_completo(self):
        return f"{self.__nome} {self.__sobrenome}"

    def checa_senha(self, senha_para_testar):
        # Verifica se a senha bate com o hash armazenado
        return crip.verify(senha_para_testar, self.__senha)


# Testando
usuario = Usuario("Maria", "Oliveira", "maria@example.com", "senhaSegura123")

print(usuario.nome_completo())  # Maria Oliveira
print(usuario.checa_senha("senhaErrada"))  # False
print(usuario.checa_senha("senhaSegura123"))  # True
# Out:
# Maria Oliveira
# False
# True
# C:\Users\Alunos\AppData\Local\Temp\ipykernel_11444\2172549421.py:9: DeprecationWarning: the method passlib.handlers.pbkdf2.pbkdf2_sha256.encrypt() is deprecated as of Passlib 1.7, and will be removed in Passlib 2.0, use .hash() instead.
#   self.__senha = crip.encrypt(senha, rounds=1000, salt_size=10)
